# %% [markdown]
# # Ghost Attack

# %%
import matplotlib
# matplotlib.use("Qt5Agg")
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import signal, stats
import mat73
import re
from neurodsp.timefrequency import compute_wavelet_transform
import os
import mne
import IPython
import seaborn as sns
import scipy
import joblib
import pickle

import statsmodels
from statsmodels import stats
from statsmodels.stats import multitest

# Import required code for visualizing example models
from fooof import FOOOF
from fooof.sim.gen import gen_power_spectrum
from fooof.sim.utils import set_random_seed
from fooof.plts.spectra import plot_spectra
from fooof.plts.annotate import plot_annotated_model
from neurodsp.utils import create_times
from neurodsp.plts.time_series import plot_time_series
from neurodsp.spectral import compute_spectrum, rotate_powerlaw
from neurodsp.plts.spectral import plot_power_spectra

## import custom functions
import sys
sys.path.append('/home/brooke/pacman/preprocessing/scripts')
import preproc_functions
import average_tfr_functions

# %%
# folders
raw_dir = '/home/brooke/pacman/raw_data'
preproc_dir = '/home/brooke/pacman/preprocessing'
tfr_dir = '/home/brooke/knight_server/remote/bstavel/pacman/preprocessing'

# subjects
sub_list = ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH026', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL10', 'LL12', 'LL13', 'LL14', 'LL17', 'LL19']

# conditions
conditions = ['TrialType <= 16']

# %% [markdown]
# ## Hippocampus

# %%
all_subs_average_hcs = calculate_ghost_attack_average(sub_list, conditions, 'hc')
all_subs_average_hc_conflict = all_subs_average_hcs[0]
# Out:
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH021/ieeg/ghost_attack/hc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH025/ieeg/ghost_attack/hc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH016/ieeg/ghost_attack/hc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/SLCH002/ieeg/ghost_attack/hc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH027/ieeg/ghost_attack/hc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH029/ieeg/ghost_attack/hc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH039/ieeg/ghost_attack/hc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH041/ieeg/ghost_attack/hc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL10/ieeg/ghost_attack/hc-tfr.h5 ...
# Not setting metadata
# log transforming
# z-scoring to baseline
# Failed to load LL10
# 'Event name "TrialType <= 16" could not be found. The following events are present in the data: 1'
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL12/ieeg/ghost_attack/hc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL12']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL13/ieeg/ghost_attack/hc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL12', 'LL13']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL14/ieeg/ghost_attack/hc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL12', 'LL13', 'LL14']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL17/ieeg/ghost_attack/hc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL12', 'LL13', 'LL14', 'LL17']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL19/ieeg/ghost_attack/hc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL12', 'LL13', 'LL14', 'LL17', 'LL19']

# %%
plot_allsub_averages(all_subs_average_hc_conflict, "Average Hippocampal TFR During Ghost Attack", 'average_hc_ghost_attack_all_subs.png', -1, 3)

# %% [markdown]
# ## OFC

# %%
all_subs_average_ofcs = calculate_ghost_attack_average(sub_list, conditions, 'ofc')
all_subs_average_ofc_conflict = all_subs_average_ofcs[0]
# Out:
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH021/ieeg/ghost_attack/ofc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH025/ieeg/ghost_attack/ofc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH016/ieeg/ghost_attack/ofc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/SLCH002/ieeg/ghost_attack/ofc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH027/ieeg/ghost_attack/ofc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH029/ieeg/ghost_attack/ofc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH039/ieeg/ghost_attack/ofc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH041/ieeg/ghost_attack/ofc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL10/ieeg/ghost_attack/ofc-tfr.h5 ...
# Not setting metadata
# log transforming
# z-scoring to baseline
# Failed to load LL10
# 'Event name "TrialType <= 16" could not be found. The following events are present in the data: 1'
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL12/ieeg/ghost_attack/ofc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL12']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL13/ieeg/ghost_attack/ofc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL12', 'LL13']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL14/ieeg/ghost_attack/ofc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL12', 'LL13', 'LL14']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL17/ieeg/ghost_attack/ofc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL12', 'LL13', 'LL14', 'LL17']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL19/ieeg/ghost_attack/ofc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL12', 'LL13', 'LL14', 'LL17', 'LL19']

# %%
plot_allsub_averages(all_subs_average_ofc_conflict, "Average OFC TFR During Ghost Attack", 'average_ofc_ghost_attack_all_subs.png', -1, 3)

# %% [markdown]
# ## Anterior Cingulate

# %%
all_subs_average_cings = calculate_ghost_attack_average(sub_list, conditions, 'cing')
all_subs_average_cing_conflict = all_subs_average_cings[0]
# Out:
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH021/ieeg/ghost_attack/cing-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH025/ieeg/ghost_attack/cing-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH016/ieeg/ghost_attack/cing-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/SLCH002/ieeg/ghost_attack/cing-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH039/ieeg/ghost_attack/cing-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH039']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH039']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL10/ieeg/ghost_attack/cing-tfr.h5 ...
# Not setting metadata
# log transforming
# z-scoring to baseline
# Failed to load LL10
# 'Event name "TrialType <= 16" could not be found. The following events are present in the data: 1'
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL12/ieeg/ghost_attack/cing-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH039', 'LL12']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL13/ieeg/ghost_attack/cing-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH039', 'LL12', 'LL13']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH039', 'LL12', 'LL13']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL17/ieeg/ghost_attack/cing-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH039', 'LL12', 'LL13', 'LL17']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL19/ieeg/ghost_attack/cing-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH039', 'LL12', 'LL13', 'LL17', 'LL19']

# %%
plot_allsub_averages(all_subs_average_cing_conflict, "Average Ant. Cingulate TFR During Ghost Attack", 'average_cing_ghost_attack_all_subs.png', -1, 3)

# %% [markdown]
# ## Amygdala

# %%
all_subs_average_amygs = calculate_ghost_attack_average(sub_list, conditions, 'amyg')
all_subs_average_amyg_conflict = all_subs_average_amygs[0]
# Out:
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH021/ieeg/ghost_attack/amyg-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH025/ieeg/ghost_attack/amyg-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH016/ieeg/ghost_attack/amyg-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/SLCH002/ieeg/ghost_attack/amyg-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH027/ieeg/ghost_attack/amyg-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH029/ieeg/ghost_attack/amyg-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH039/ieeg/ghost_attack/amyg-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH041/ieeg/ghost_attack/amyg-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL10/ieeg/ghost_attack/amyg-tfr.h5 ...
# Not setting metadata
# log transforming
# z-scoring to baseline
# Failed to load LL10
# 'Event name "TrialType <= 16" could not be found. The following events are present in the data: 1'
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL12/ieeg/ghost_attack/amyg-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL12']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL13/ieeg/ghost_attack/amyg-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL12', 'LL13']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL14/ieeg/ghost_attack/amyg-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL12', 'LL13', 'LL14']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL17/ieeg/ghost_attack/amyg-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL12', 'LL13', 'LL14', 'LL17']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL19/ieeg/ghost_attack/amyg-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL12', 'LL13', 'LL14', 'LL17', 'LL19']

# %%
plot_allsub_averages(all_subs_average_amyg_conflict, "Average Amygdala TFR During Ghost Attack", 'average_amyg_ghost_attack_all_subs.png', -1, 3)

# %% [markdown]
# # Other Regions

# %% [markdown]
# ## dlPFC

# %%
all_subs_average_dlpfcs = calculate_ghost_attack_average(sub_list, conditions, 'dlpfc')
all_subs_average_dlpfc_conflict = all_subs_average_dlpfcs[0]
# Out:
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH021/ieeg/ghost_attack/dlpfc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH025/ieeg/ghost_attack/dlpfc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH016/ieeg/ghost_attack/dlpfc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/SLCH002/ieeg/ghost_attack/dlpfc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH027/ieeg/ghost_attack/dlpfc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH039/ieeg/ghost_attack/dlpfc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH039']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH039']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL10/ieeg/ghost_attack/dlpfc-tfr.h5 ...
# Not setting metadata
# log transforming
# z-scoring to baseline
# Failed to load LL10
# 'Event name "TrialType <= 16" could not be found. The following events are present in the data: 1'
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL12/ieeg/ghost_attack/dlpfc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH039', 'LL12']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL13/ieeg/ghost_attack/dlpfc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH039', 'LL12', 'LL13']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL14/ieeg/ghost_attack/dlpfc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH039', 'LL12', 'LL13', 'LL14']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL17/ieeg/ghost_attack/dlpfc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH039', 'LL12', 'LL13', 'LL14', 'LL17']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL19/ieeg/ghost_attack/dlpfc-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH039', 'LL12', 'LL13', 'LL14', 'LL17', 'LL19']

# %%
plot_allsub_averages(all_subs_average_dlpfc_conflict, "Average dlPFC TFR During Ghost Attack", 'average_dlpfc_ghost_attack_all_subs.png', -1, 3)

# %% [markdown]
# ## Insula

# %%
all_subs_average_insulas = calculate_ghost_attack_average(sub_list, conditions, 'insula')
all_subs_average_insula_conflict = all_subs_average_insulas[0]
# Out:
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH021/ieeg/ghost_attack/insula-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH025/ieeg/ghost_attack/insula-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH016/ieeg/ghost_attack/insula-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/SLCH002/ieeg/ghost_attack/insula-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH027/ieeg/ghost_attack/insula-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH029/ieeg/ghost_attack/insula-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH041/ieeg/ghost_attack/insula-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH041']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH041']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL12/ieeg/ghost_attack/insula-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH041', 'LL12']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH041', 'LL12']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH041', 'LL12']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH041', 'LL12']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH041', 'LL12']

# %%
plot_allsub_averages(all_subs_average_insula_conflict, "Average Insula TFR During Ghost Attack", 'average_insula_ghost_attack_all_subs.png', -1, 3)

# %% [markdown]
# ## EC

# %%
all_subs_average_ecs = calculate_ghost_attack_average(sub_list, conditions, 'ec')
all_subs_average_ec_conflict = all_subs_average_ecs[0]
# Out:
# currently used subs: []
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH025/ieeg/ghost_attack/ec-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH025']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH016/ieeg/ghost_attack/ec-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH025', 'BJH016']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/SLCH002/ieeg/ghost_attack/ec-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH025', 'BJH016', 'SLCH002']
# currently used subs: ['BJH025', 'BJH016', 'SLCH002']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH027/ieeg/ghost_attack/ec-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH025', 'BJH016', 'SLCH002', 'BJH027']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH029/ieeg/ghost_attack/ec-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH039/ieeg/ghost_attack/ec-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH041/ieeg/ghost_attack/ec-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL10/ieeg/ghost_attack/ec-tfr.h5 ...
# Not setting metadata
# log transforming
# z-scoring to baseline
# Failed to load LL10
# 'Event name "TrialType <= 16" could not be found. The following events are present in the data: 1'
# currently used subs: ['BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041']
# currently used subs: ['BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041']
# currently used subs: ['BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041']
# currently used subs: ['BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/LL19/ieeg/ghost_attack/ec-tfr.h5 ...
# Adding metadata with 5 columns
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH025', 'BJH016', 'SLCH002', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL19']

# %%
plot_allsub_averages(all_subs_average_ec_conflict, "Average Entorhinal Cortex TFR During Ghost Attack", 'average_ec_ghost_attack_all_subs.png', -1, 3)
